# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
cars = pd.read_csv(r"https://drive.usercontent.google.com/download?id=1snaJijs8zuQt7v1gwSqwBXaIrIiIkkvL&export=download&authuser=0&confirm=t&uuid=580a56c6-2a4b-4226-835e-fdfb8189ea0d&at=ALoNOgmd39EJa9uKE5AWmx_k60wP:1748761611058")

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
cars.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
cars.set_index('name')
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
# [398 rows x 8 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
cars['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
cars["Hp/weight"] = cars['horsepower'] / cars['weight']

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
cars[(cars['horsepower'] == cars['horsepower'].max())]['name']
# Out:
# 116    pontiac grand prix
# Name: name, dtype: object

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
cars[cars['mpg']>=35]['name'].count()
# Out:
# np.int64(36)

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
cars[(cars['horsepower']> 100) & (cars['weight'] < 3000)]['origin'].mode()
# Out:
# 0    usa
# Name: origin, dtype: object

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
cars[cars['origin'] == 'japan']['acceleration'].mean().round(2)
# Out:
# np.float64(16.17)

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
cars[cars['mpg'] == cars['mpg'].max()]['model_year']
# Out:
# 322    80
# Name: model_year, dtype: int64

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
cars[cars['Hp/weight'] == cars['Hp/weight'].max()]['name']
# Out:
# 13    buick estate wagon (sw)
# Name: name, dtype: object

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
import matplotlib.pyplot as plt

# Group by both 'model_year' and 'origin'
grouped = cars.groupby(['model_year', 'origin'])['mpg'].mean().unstack()

# Plot
grouped.plot()
plt.xlabel("Year")
plt.ylabel("Average MPG")
plt.title("Average MPG Over the Years by Origin")
plt.legend(title='Origin')
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatterplot
sns.scatterplot(
    data=cars,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=['japan', 'europe', 'usa'],
    sizes=(20, 200),
    palette='muted',
    alpha=0.7
)

# Add axis labels and title
plt.title('Horsepower vs Weight by Origin (Size ~ MPG)')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')  # Moves legend outside
plt.tight_layout()
plt.show()
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
grouped = cars.groupby('name')

# Prepare data: model year count, std of mpg, mean mpg, total count
consistency_df = grouped.agg(
    model_years=('model_year', lambda x: x.nunique()),
    mpg_std=('mpg', 'std'),
    mpg_mean=('mpg', 'mean'),
    count=('name', 'count')
).reset_index()

# Filter: appeared in >1 model year, std(mpg) < 1.0, and at least 2 entries
filtered = consistency_df[
    (consistency_df['model_years'] > 1) &
    (consistency_df['mpg_std'] < 1.0) &
    (consistency_df['count'] >= 2)
]

# Find minimum std among filtered
min_std = filtered['mpg_std'].min()
most_consistent = filtered[filtered['mpg_std'] == min_std]

# Bonus: Sort by number of appearances (desc), then mpg_mean (desc)
sorted_consistent = most_consistent.sort_values(by=['count', 'mpg_mean'], ascending=[False, False])

# Show final result
sorted_consistent[['name', 'count', 'mpg_mean', 'mpg_std']]
# Out:
#             name  count  mpg_mean  mpg_std
# 95  datsun pl510      2      27.0      0.0

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
